# %% [markdown]
# #### Relevant url:
# https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25#:~:text=There%20are%20two%20ways%20to,as%20part%20of%20their%20profile

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#Shortened code to fetch the first (i.e. most recent) 100 tweets that contains the phrase data science 
pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"data science"').get_items(), 100))
# Out:
#                                                   url  \
# 0   https://twitter.com/siele_justus/status/157303...
# 1   https://twitter.com/DVCuervo/status/1573037481...
# 2   https://twitter.com/machinelearnflx/status/157...
# 3   https://twitter.com/DonBogotano/status/1573037...
# 4   https://twitter.com/AbdnCHDS/status/1573036848...
# ..                                                ...
# 95  https://twitter.com/Willv4_0/status/1573023829...
# 96  https://twitter.com/DataSciSalon/status/157302...
# 97  https://twitter.com/KaskadaInc/status/15730235...
# 98  https://twitter.com/CPetersen_CS/status/157302...
# 99  https://twitter.com/MatildaKohler3/status/1573...
#
#                         date  \
# 0  2022-09-22 19:52:36+00:00
# 1  2022-09-22 19:52:15+00:00
# 2  2022-09-22 19:51:39+00:00
# 3  2022-09-22 19:50:24+00:00
# 4  2022-09-22 19:49:45+00:00
# ..                       ...
# 95 2022-09-22 18:58:01+00:00
# 96 2022-09-22 18:57:43+00:00
# 97 2022-09-22 18:56:55+00:00
# 98 2022-09-22 18:54:39+00:00
# 99 2022-09-22 18:49:23+00:00
#
#                                               content  \
# 0   @HarunMbaabu if possible, organise for data sc...
# 1   #SEOnderground el súper equipo de data science...
# 2   eugeneyan/applied-ml: 📚 Papers &amp; tech blog...
# 3   Una charla muy interesante la de @inkasunka so...
# 4   Check out @aberdeenuni Open Access Week. Lots ...
# ..                                                ...
# 95  4 Essential Python Projects for Beginners in D...
# 96  @DataSciSalon is partnering with @CIOApplicati...
# 97  Kaskada provides rapid development and trainin...
# 98  A5) [agreeing with the gang] And, enabling cit...
# 99  2 in 1 ชุดวิชา Data Science + วิชา Attacking t...
#
#                                       renderedContent                   id  \
# 0   @HarunMbaabu if possible, organise for data sc...  1573037567339028483
# 1   #SEOnderground el súper equipo de data science...  1573037481120890881
# 2   eugeneyan/applied-ml: 📚 Papers &amp; tech blog...  1573037327282323462
# 3   Una charla muy interesante la de @inkasunka so...  1573037012457820168
# 4   Check out @aberdeenuni Open Access Week. Lots ...  1573036848867328002
# ..                                                ...                  ...
# 95  4 Essential Python Projects for Beginners in D...  1573023829840265217
# 96  @DataSciSalon is partnering with @CIOApplicati...  1573023756142137344
# 97  Kaskada provides rapid development and trainin...  1573023552776769536
# 98  A5) [agreeing with the gang] And, enabling cit...  1573022985581125632
# 99  2 in 1 ชุดวิชา Data Science + วิชา Attacking t...  1573021658142515201
#
#                                                  user  replyCount  \
# 0   {'username': 'siele_justus', 'id': 12463875731...           0
# 1   {'username': 'DVCuervo', 'id': 277587293, 'dis...           0
# 2   {'username': 'machinelearnflx', 'id': 48208042...           0
# 3   {'username': 'DonBogotano', 'id': 345505415, '...           1
# 4   {'username': 'AbdnCHDS', 'id': 935544921246793...           0
# ..                                                ...         ...
# 95  {'username': 'Willv4_0', 'id': 31139206, 'disp...           0
# 96  {'username': 'DataSciSalon', 'id': 82901872604...           0
# 97  {'username': 'KaskadaInc', 'id': 9617782160703...           0
# 98  {'username': 'CPetersen_CS', 'id': 458979801, ...           0
# 99  {'username': 'MatildaKohler3', 'id': 153580131...           0
#
#     retweetCount  likeCount  quoteCount  ...  \
# 0              0          0           0  ...
# 1              0          1           0  ...
# 2              0          1           0  ...
# 3              0          1           0  ...
# 4              1          1           0  ...
# ..           ...        ...         ...  ...
# 95             1          0           0  ...
# 96             0          0           0  ...
# 97             1          0           0  ...
# 98             2          1           0  ...
# 99             0          0           0  ...
#
#                                                 media retweetedTweet  \
# 0                                                None           None
# 1   [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 2                                                None           None
# 3   [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 4                                                None           None
# ..                                                ...            ...
# 95                                               None           None
# 96                                               None           None
# 97  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...           None
# 98                                               None           None
# 99                                               None           None
#
#                                           quotedTweet inReplyToTweetId  \
# 0                                                None              NaN
# 1                                                None              NaN
# 2                                                None              NaN
# 3                                                None              NaN
# 4   {'url': 'https://twitter.com/OpenResearchUoA/s...              NaN
# ..                                                ...              ...
# 95                                               None              NaN
# 96                                               None              NaN
# 97                                               None              NaN
# 98                                               None              NaN
# 99                                               None              NaN
#
#    inReplyToUser                                     mentionedUsers  \
# 0           None  [{'username': 'HarunMbaabu', 'id': 11935383927...
# 1           None                                               None
# 2           None                                               None
# 3           None  [{'username': 'inkasunka', 'id': 314778774, 'd...
# 4           None  [{'username': 'aberdeenuni', 'id': 20427406, '...
# ..           ...                                                ...
# 95          None                                               None
# 96          None  [{'username': 'DataSciSalon', 'id': 8290187260...
# 97          None                                               None
# 98          None  [{'username': 'nyike', 'id': 16693331, 'displa...
# 99          None                                               None
#
#    coordinates place                                           hashtags  \
# 0         None  None                                               None
# 1         None  None                                    [SEOnderground]
# 2         None  None                     [DataScience, MachineLearning]
# 3         None  None                               [SEOnderground, SEO]
# 4         None  None                                               None
# ..         ...   ...                                                ...
# 95        None  None                                               None
# 96        None  None                                               None
# 97        None  None  [data, development, ml, machinelearning, dataa...
# 98        None  None                                          [ciochat]
# 99        None  None                                               None
#
#    cashtags
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ..      ...
# 95     None
# 96     None
# 97     None
# 98     None
# 99     None
#
# [100 rows x 27 columns]

# %% [markdown]
# #### The TwitterSearchScraper uses Twitter’s advanced search; for an in depth run down of all its capabilities check out this table — I cannot recommend it enough!

# %%
#To find all tweets about pizza in Los Angeles. This can be achieved using the following code:

df_city = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza near:"Los Angeles" within:10km').get_items(), 50))[['date', 'content']]

# %% [markdown]
# #### OR

# %%
# Instead of using the city’s name you can use its coordinates:

loc = '34.052235, -118.243683, 10km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'pizza geocode:"{}"'.format(loc)).get_items(), 50))[['date', 'content']]

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     50 non-null     datetime64[ns, UTC]
#  1   content  50 non-null     object
# dtypes: datetime64[ns, UTC](1), object(1)
# memory usage: 928.0+ bytes

# %%
df_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     50 non-null     datetime64[ns, UTC]
#  1   content  50 non-null     object
# dtypes: datetime64[ns, UTC](1), object(1)
# memory usage: 928.0+ bytes

# %%
loc = '34.052235, -118.243683, 100km'
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'GoDaddy geocode:"{}"'.format(loc)).get_items(), 5000))[['user', 'date','content']]

df_coord['user_location'] =  df_coord['user'].apply(lambda x: x['location'])
df_coord['user'] =  df_coord['user'].apply(lambda x: x['username'])

# %%
df_coord
# Out:
#                user                      date  \
# 0          tayvano_ 2022-09-22 13:19:55+00:00
# 1         sethakatz 2022-09-21 20:40:37+00:00
# 2         RAY_UR6IX 2022-09-20 20:30:07+00:00
# 3        LigLending 2022-09-20 17:57:09+00:00
# 4      edgybranding 2022-09-20 16:03:47+00:00
# ...             ...                       ...
# 1482  FreddieCarthy 2010-10-02 05:20:58+00:00
# 1483    jasonlankow 2010-08-02 22:41:51+00:00
# 1484       __loganc 2010-05-27 03:27:13+00:00
# 1485       grhansen 2010-04-07 17:52:01+00:00
# 1486      jonirvine 2010-03-12 00:43:43+00:00
#
#                                                 content      user_location
# 0     2️⃣ Liquid CEX\nData breach / PII extraction\n...    Los Angeles, CA
# 1     @RSMUSLLP\n@allenmatkins\nCathay Bank\n@ClarkB...    Los Angeles, CA
# 2     @nandoodles n the last 2 weeks, I notified MyP...        Temecula Ca
# 3     Proudly presenting https://t.co/BHqqQMxWaD. Ch...         Downey, CA
# 4     Some things you should know about Dan/GoDaddy ...   Santa Monica, CA
# ...                                                 ...                ...
# 1482  I downloaded the GoDaddy iPhone app and immedi...                PDX
# 1483  Cool - 30% off on godaddy.com registrations - ...    meepzorp.eth ꜩ.
# 1484  @lilzaphod just an fyi, looks like lilzaphod.c...    Los Angeles, CA
# 1485  Since searching for hosting services, it appea...     Stillwater, MN
# 1486  @djword doesn't look like it is available when...  Portland, OR, USA
#
# [1487 rows x 4 columns]

# %%
df_coord.to_csv('tweets within 100 Km of Los Angeles location.csv')

# %%
#Initally 'user' column consisted of dictionary of users in each row 
df_coord['user'][0]
# Out:
# {'username': 'tayvano_',
#  'id': 19748227,
#  'displayname': 'Tay 🦊💙',
#  'description': 'building @metamask 🦊 prev ceo-ing @mycrypto 💙 part-time wizard. lethal founder. top assassin ✨ dont come @ me less youre ready to battle 🗡 💖  tay.eth',
#  'rawDescription': 'building @metamask 🦊 prev ceo-ing @mycrypto 💙 part-time wizard. lethal founder. top assassin ✨ dont come @ me less youre ready to battle 🗡 💖  tay.eth',
#  'descriptionUrls': None,
#  'verified': True,
#  'created': datetime.datetime(2009, 1, 30, 1, 46, 41, tzinfo=datetime.timezone.utc),
#  'followersCount': 57382,
#  'friendsCount': 6623,
#  'statusesCount': 20900,
#  'favouritesCount': 17492,
#  'listedCount': 1276,
#  'mediaCount': 2440,
#  'location': 'Los Angeles, CA',
#  'protected': False,
#  'linkUrl': 'https://metamask.io/',
#  'linkTcourl': 'https://t.co/KiKvfYKyw9',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1558729910671183873/RHtt9Zgf_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/19748227/1405371955',
#  'label': None}

# %%
df= pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'GoDaddy').get_items(), 10000))[['user','date', 'content']]

df['user_location'] =  df['user'].apply(lambda x: x['location'])
df
# Out:
#                                                    user  \
# 0     {'username': 'Braxtonmanley', 'id': 33365139, ...
# 1     {'username': 'SGEmail2', 'id': 154764207240801...
# 2     {'username': 'Rachelgaffney', 'id': 19592472, ...
# 3     {'username': 'marcflood', 'id': 21065058, 'dis...
# 4     {'username': 'GoDaddyOSS', 'id': 9595630949376...
# ...                                                 ...
# 9995  {'username': 'TheGoopyGhost', 'id': 35699406, ...
# 9996  {'username': 'CmHazza', 'id': 1345464922831007...
# 9997  {'username': 'gettaxomate', 'id': 818987754952...
# 9998  {'username': 'metanhs', 'id': 1371703825443213...
# 9999  {'username': 'ecarlesi', 'id': 19444180, 'disp...
#
#                           date  \
# 0    2022-09-22 22:10:24+00:00
# 1    2022-09-22 22:10:24+00:00
# 2    2022-09-22 22:09:49+00:00
# 3    2022-09-22 22:06:10+00:00
# 4    2022-09-22 21:59:46+00:00
# ...                        ...
# 9995 2022-08-16 10:51:07+00:00
# 9996 2022-08-16 10:38:20+00:00
# 9997 2022-08-16 10:23:29+00:00
# 9998 2022-08-16 10:18:29+00:00
# 9999 2022-08-16 10:18:05+00:00
#
#                                                 content  user_location
# 0     @iamdulma Super underrated graphic design app:...     Austin, TX
# 1     @GoDaddy - online form error- \nThere was an e...
# 2     @GoDaddy I am now on Day #4 of my website not ...      Dallas,Tx
# 3     GoDaddy Alternatives and Competitors https://t...     Dallas, TX
# 4     Experimentation on the brain? Check out our la...
# ...                                                 ...            ...
# 9995  The @GoDaddy tech/SEO expert who answered my c...
# 9996  @kotakmakan @cm0102legends This. I used WiX in...
# 9997  Wave Accounting has some worth its cost additi...
# 9998  @eddywangping @GoDaddy needs to sort its algor...  United States
# 9999   Possible threat on hxxp://mivtop[.]com  #godaddy    Roma, Lazio
#
# [10000 rows x 4 columns]

# %%
df['user_location'].unique()
# Out:
# array(['Austin, TX', '', 'Dallas,Tx', ..., 'Waterville Maine', 'DK',
#        'Logo for your startup in 5min→'], dtype=object)

# %%
df.to_csv('10000 tweets of GoDaddy with location.csv')
